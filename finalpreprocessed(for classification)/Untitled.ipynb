# %%
# %cd /teamspace/studios/this_studio
# Out:
# /teamspace/studios/this_studio

# %%
# !git clone https://github.com/Sahilvaghasiyaa/-Market-Trend-classifier-and-analyzer.git
# Out:
# Cloning into '-Market-Trend-classifier-and-analyzer'...
